# %% [markdown]
# ## Integrador API OPTA

# %%
import requests
import re
from bs4 import BeautifulSoup
import os
import json
from datetime import datetime
import time
import random
import pandas as pd
import re
from datetime import datetime, timedelta,date
import warnings  # Importa el módulo warnings, que maneja los mensajes de advertencia en Python.
import sw_scraping_fun as swf
import sw_json2csv_fun as swj


with open("config/config.json", "r", encoding="utf-8") as f:
    config = json.load(f)

ruta_dest=config['dummy_ori']
liga_seleccionada= config['dummy_competition']

warnings.filterwarnings("ignore")

# %%
def extraer_datos_partido(match,fixtures,token):
    df_game=swf.get_datos_partido(match,fixtures,token)
    data=swj.get_events(df_game)

    return data

# %% [markdown]
# # Scraping + Parseo

# %%
metadata = pd.read_excel("config/metadata.xlsx")
metadata=metadata[metadata.procesar_sn==1]

# %% [markdown]
# ## API -> JSON
#
# Se extrae un fichero json de cada partido. Posteriormente, se parsea y se transforma en csv.
# Un partido contiene la siguiente información, a nivel partido:
# - *matchdata*: atributos del partido
# - *playerdata*: atributos de jugadores
# - *teamdata*: atributos de los equipos
# - *eventdata*: eventing
#
# Adicionalmente, se incorporan datos agregados de equipos (teamstats), extraidos mediante selenium.

# %%
ficheros = [f for f in os.listdir(os.path.join(os.getcwd(),"fixtures")) if f.endswith(('.xlsx', '.xls')) and "$" not in f]
fixtures = pd.DataFrame()
for i in ficheros:
    fi = pd.read_excel(os.path.join(os.getcwd(),"fixtures",i))
    fixtures=pd.concat([fixtures,fi])

# %%
all_fixtures_df=pd.DataFrame()
for i,j in metadata.iterrows():
        ruta_dest = j['origen']
        season= j['season']
        comp = j['competicion_id']
        #comps.append(comp)
        #seasons.append(season)
        fixtures_url = j['url']
        fichero_liga = "matches_{}_{}.xlsx".format(comp.lower(),season)
    
    
        
        if fichero_liga in ficheros:
            all_fixtures=pd.read_excel(os.path.join(os.getcwd(),"fixtures")+"/{}".format(fichero_liga))
            all_fixtures = all_fixtures.drop_duplicates(subset="match_id",keep='first')
        else:
            all_fixtures = swf.scrape_fixtures(metadata,fixtures_url)
            if all_fixtures.shape[0]>0:
                all_fixtures['season'] = season
                all_fixtures['competition'] = comp
        all_fixtures['date'] = all_fixtures['date'].fillna(all_fixtures[all_fixtures['date'].isna()==False]['date'].values[-1])
        all_fixtures['dia_id']=all_fixtures.date.apply(lambda x: datetime.fromisoformat(x.replace("Z", "")).date())
        all_fixtures_df=pd.concat([all_fixtures_df,all_fixtures])
# Out:
# torneo_name: esp-laligaeasports_2025-2026
# torneo_id: 80zg2v1cuqcfhphn56u4qpyqc
# ✅ Estructura de carpetas creada (si no existía).
# Error: Añadiendo token por defecto
# Leyendo sdapi_outlet_key desde config/config.json...
# sdapi_outlet_key: ft1tiv1inq7v1sk3y9tv12yh5
# Fixture guardado exitosamente.
# No existen datos extra: fixtures
# No existen datos extra: results

# %% [markdown]
# **Nota**: si no se guardan partidos de la competición seleccionada en *config* y la competición ya ha finalizado (se han disputado todos los partidos), marcar *actual_sn = 0* en el fichero.

# %%
df_partidos = all_fixtures_df[all_fixtures_df.dia_id<date.today()]
for i in df_partidos.competition.unique():
    print("Partidos ya jugados: {} ({} totales en {})".format(df_partidos[df_partidos.competition==i].shape[0],all_fixtures_df[all_fixtures_df.competition==i].shape[0],i))
# Out:
# Partidos ya jugados: 380 (380 totales en esp-laligaeasports)

# %%
df_partidos.head()
# Out:
#           competition     season         date    home_team  \
# 0  esp-laligaeasports  2025-2026  2026-05-24Z   Villarreal
# 1  esp-laligaeasports  2025-2026  2026-05-23Z       Girona
# 2  esp-laligaeasports  2025-2026  2026-05-23Z     Valencia
# 3  esp-laligaeasports  2025-2026  2026-05-23Z  Real Madrid
# 4  esp-laligaeasports  2025-2026  2026-05-23Z     Mallorca
#
#             away_team stadium                   match_id  \
# 0  Atlético de Madrid    None  3xcjz4isjg101zf0d40lxkglw
# 1               Elche    None  3y3gz2ufpcbu5vkgph7jyg74k
# 2           Barcelona    None  3xq4alyjtlltd6j11gckoxvkk
# 3       Athletic Club    None  3wz71k4469ny273fw5c1yavx0
# 4         Real Oviedo    None  3wljbdagmhpi6h7viwogz9ul0
#
#                                                  URL      dia_id
# 0  https://www.scoresway.com/en_GB/soccer/primera...  2026-05-24
# 1  https://www.scoresway.com/en_GB/soccer/primera...  2026-05-23
# 2  https://www.scoresway.com/en_GB/soccer/primera...  2026-05-23
# 3  https://www.scoresway.com/en_GB/soccer/primera...  2026-05-23
# 4  https://www.scoresway.com/en_GB/soccer/primera...  2026-05-23

# %%
partido = df_partidos.match_id.values[-1]
partido
# Out:
# '1f9e25njwyjk6ruheatqgglw'

# %%
data=extraer_datos_partido(
                    partido,
                    df_partidos,
                    swf.obtener_sdapi_outlet_key(metadata.url.values[0]))
# Out:
# Error: Añadiendo token por defecto
# Leyendo sdapi_outlet_key desde config/config.json...
# https://api.performfeeds.com/soccerdata/matchevent/ft1tiv1inq7v1sk3y9tv12yh5/1f9e25njwyjk6ruheatqgglw?_rt=c&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
# ⏳ Esperando 4.15 segundos antes de descargar (intento 1/3)...
# ✅ Guardado: 2025-08-15Z_Girona_Rayo Vallecano_1f9e25njwyjk6ruheatqgglw.json

# %%
data.keys()
# Out:
# dict_keys(['eventData', 'matchData', 'teamData', 'playerData'])

# %% [markdown]
# #### Eventos

# %%
events= data['eventData']
print("Nº filas: {}".format(events.shape[0]))
events.head()
# Out:
# Nº filas: 1716
#            id  eventId  typeId  periodId  timeMin  timeSec  \
# 0  2835039373        1      34        16        0        0
# 1  2835040341        1      34        16        0        0
# 2  2835057147        2      32         1        0        0
# 3  2835057151        2      32         1        0        0
# 4  2835057157        3       1         1        0        0
#
#                 contestantId  outcome     x     y  ... relatedEventId  \
# 0  3budh3j9xivsid3ptm8ptpy4k        1   0.0   0.0  ...            NaN
# 1  7h7eg7q7dbwvzww78h9d5eh0h        1   0.0   0.0  ...            NaN
# 2  7h7eg7q7dbwvzww78h9d5eh0h        1   0.0   0.0  ...            NaN
# 3  3budh3j9xivsid3ptm8ptpy4k        1   0.0   0.0  ...            NaN
# 4  3budh3j9xivsid3ptm8ptpy4k        1  49.8  49.9  ...            NaN
#
#   relatedPlayerId is_penalty isGoal minute  second  oppositionTeamName  \
# 0             NaN        NaN      0      0       0              Girona
# 1             NaN        NaN      0      0       0      Rayo Vallecano
# 2             NaN        NaN      0      0       0      Rayo Vallecano
# 3             NaN        NaN      0      0       0              Girona
# 4             NaN        NaN      0      0       0              Girona
#
#   time_seconds position  isFirstEleven
# 0            0      NaN            NaN
# 1            0      NaN            NaN
# 2            0      NaN            NaN
# 3            0      NaN            NaN
# 4            0       FW            1.0
#
# [5 rows x 201 columns]

# %% [markdown]
# #### Dimensiones:
#
# - Partido
# - Equipos
# - Jugadores

# %%
df_match= data['matchData']
df_match.head()
# Out:
#                     matchId                        id coverageLevel  \
# 0  1f9e25njwyjk6ruheatqgglw  1f9e25njwyjk6ruheatqgglw            13
#
#           date       time   localDate localTime week  numberOfPeriods  \
# 0  2025-08-15Z  17:00:00Z  2025-08-15  19:00:00    1                2
#
#    periodLength  ... away_position             competition_id  \
# 0            45  ...          away  34pl8szyvrbwcmfkuocjm3r6t
#
#    competition_name competition_knownName competition_sponsorName  \
# 0  Primera División       Spanish La Liga        LALIGA EA SPORTS
#
#   competition_competitionCode competition_competitionFormat  \
# 0                         PRD               Domestic league
#
#                        venueName expandedMaxMinute matchStatus
# 0  Estadi Municipal de Montilivi               104      Played
#
# [1 rows x 38 columns]

# %%
df_teams= data['teamData']
df_teams.head()
# Out:
#                       teamId        teamName shortName  \
# 0  7h7eg7q7dbwvzww78h9d5eh0h          Girona    Girona
# 1  3budh3j9xivsid3ptm8ptpy4k  Rayo Vallecano      Rayo
#
#                officialName code field country                   matchId  \
# 0                 Girona FC  GIR  home   Spain  1f9e25njwyjk6ruheatqgglw
# 1  Rayo Vallecano de Madrid  RAY  away   Spain  1f9e25njwyjk6ruheatqgglw
#
#    scores.halftime  scores.fulltime
# 0                0                1
# 1                3                3

# %%
df_players= data['playerData']
print("Nº filas: {}".format(df_players.shape[0]))
df_players.head()
# Out:
# Nº filas: 45
#   field_position                   playerId value_TeamPlayerFormation shirtNo  \
# 0              1   9h6xf4ac4rpsjpummcdx26z9                         1      13
# 1              2  38dhmhce7deuqgqmc3p7nhai2                         2       2
# 2              2  amt4voyjzhnvr55t08hzlw50q                         3       3
# 3              3   u04ao1ldrjjesgqq52o7ghqt                         4      17
# 4              2  533095rnz0k8mxqe6gzn0mfo5                         5      24
#
#   value_TeamFormation                     teamId                   matchId  \
# 0                   8  3budh3j9xivsid3ptm8ptpy4k  1f9e25njwyjk6ruheatqgglw
# 1                   8  3budh3j9xivsid3ptm8ptpy4k  1f9e25njwyjk6ruheatqgglw
# 2                   8  3budh3j9xivsid3ptm8ptpy4k  1f9e25njwyjk6ruheatqgglw
# 3                   8  3budh3j9xivsid3ptm8ptpy4k  1f9e25njwyjk6ruheatqgglw
# 4                   8  3budh3j9xivsid3ptm8ptpy4k  1f9e25njwyjk6ruheatqgglw
#
#   field  isFirstEleven position     playerName subbedOutPlayerId  \
# 0  away              1       GK     A. Batalla               NaN
# 1  away              1       DR       A. Rațiu               NaN
# 2  away              1       DC  Pep Chavarría               NaN
# 3  away              1       MC     Unai López               NaN
# 4  away              1       DL     F. Lejeune               NaN
#
#    subbedInExpandedMinute  subbedInPeriod_value           subbedInPlayerId  \
# 0                     NaN                   NaN                        NaN
# 1                     NaN                   NaN                        NaN
# 2                     NaN                   NaN                        NaN
# 3                     NaN                   NaN  8onruhr4es313aq52xsl7nxlh
# 4                     NaN                   NaN                        NaN
#
#    subbedOutExpandedMinute  subbedOutPeriod_value
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                     80.0                    2.0
# 4                      NaN                    NaN

# %% [markdown]
# #### Datos Agregados por Equipo

# %%
df_teamstats=swf.get_teamstats(df_partidos[df_partidos.match_id==df_partidos.match_id.values[-1]],ruta_dest)
print("Nº filas: {}".format(df_teamstats.shape[0]))
df_teamstats.head()
# Out:
# Nº filas: 2
#   field  Aerial duels won  Blocked shots  Clearances  Corners won  Crosses  \
# 0  away             0.516              1          18            4       15
# 1  home             0.484              3          18            2       12
#
#    Crossing accuracy  Duels success rate  Fouls conceded  Goals  ...  \
# 0              0.600               0.523              17      3  ...
# 1              0.167               0.477               8      1  ...
#
#    Red cards  Shooting accuracy  Shots  Shots inside the box  Shots on target  \
# 0          0              0.313     16                    12                5
# 1          1              0.286      7                     3                2
#
#    Shots outside the box  Tackles  Tackles success rate  Yellow cards  \
# 0                      4       27                 0.481             1
# 1                      4       13                 0.692             0
#
#                     matchId
# 0  1f9e25njwyjk6ruheatqgglw
# 1  1f9e25njwyjk6ruheatqgglw
#
# [2 rows x 27 columns]
